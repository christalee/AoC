# %%
def input(filename):
    with open(filename, 'r') as input:
        data = [x.strip() for x in input]

    return data

# %%
triangles = input('day3.txt')
count = 0
i = 0

# %%
# Turn the input string into a list of numbers
htri = [x.split() for x in triangles]

# Group those numbers into sets of 3
i = range(0, len(htri), 3)
vtri = [y for x in i for y in zip(htri[x], htri[x+1], htri[x+2])]

# %%
z = list(map(int, vtri[0]))
z
# Out:
# [4, 419, 424]

# %%
htri
# Out:
# [['4', '21', '894'],
#  ['419', '794', '987'],
#  ['424', '797', '125'],
#  ['651', '305', '558'],
#  ['655', '631', '963'],
#  ['2', '628', '436'],
#  ['736', '50', '363'],
#  ['657', '707', '408'],
#  ['252', '705', '98'],
#  ['532', '173', '878'],
#  ['574', '792', '854'],
#  ['157', '737', '303'],
#  ['468', '76', '580'],
#  ['502', '503', '434'],
#  ['467', '567', '310'],
#  ['911', '911', '391'],
#  ['791', '913', '925'],
#  ['174', '49', '532'],
#  ['796', '803', '426'],
#  ['800', '132', '710'],
#  ['273', '722', '711'],
#  ['388', '576', '551'],
#  ['17', '936', '676'],
#  ['371', '712', '141'],
#  ['692', '738', '913'],
#  ['745', '805', '975'],
#  ['381', '140', '680'],
#  ['859', '344', '336'],
#  ['109', '148', '877'],
#  ['835', '441', '716'],
#  ['355', '288', '669'],
#  ['968', '259', '517'],
#  ['979', '350', '773'],
#  ['134', '222', '347'],
#  ['614', '279', '628'],
#  ['510', '140', '590'],
#  ['901', '581', '707'],
#  ['958', '933', '680'],
#  ['95', '558', '766'],
#  ['676', '739', '739'],
#  ['890', '40', '825'],
#  ['280', '735', '297'],
#  ['593', '354', '701'],
#  ['555', '756', '730'],
#  ['39', '656', '853'],
#  ['399', '660', '14'],
#  ['293', '685', '48'],
#  ['109', '374', '42'],
#  ['260', '608', '680'],
#  ['306', '885', '603'],
#  ['49', '683', '810'],
#  ['125', '513', '512'],
#  ['706', '600', '143'],
#  ['728', '138', '658'],
#  ['410', '673', '27'],
#  ['617', '872', '89'],
#  ['923', '733', '103'],
#  ['462', '674', '95'],
#  ['352', '718', '191'],
#  ['129', '351', '173'],
#  ['648', '839', '828'],
#  ['332', '829', '789'],
#  ['947', '44', '214'],
#  ['768', '576', '184'],
#  ['672', '900', '601'],
#  ['98', '672', '738'],
#  ['368', '926', '539'],
#  ['271', '300', '372'],
#  ['141', '844', '261'],
#  ['731', '426', '205'],
#  ['734', '979', '792'],
#  ['16', '703', '888'],
#  ['133', '682', '323'],
#  ['428', '784', '182'],
#  ['398', '171', '394'],
#  ['154', '845', '425'],
#  ['643', '14', '775'],
#  ['695', '849', '432'],
#  ['22', '227', '464'],
#  ['490', '544', '485'],
#  ['474', '701', '910'],
#  ['902', '629', '10'],
#  ['996', '680', '67'],
#  ['91', '908', '75'],
#  ['653', '600', '845'],
#  ['439', '53', '117'],
#  ['480', '552', '860'],
#  ['156', '144', '46'],
#  ['492', '359', '597'],
#  ['408', '473', '614'],
#  ['469', '343', '737'],
#  ['777', '438', '149'],
#  ['803', '114', '676'],
#  ['78', '835', '753'],
#  ['567', '230', '707'],
#  ['542', '738', '49'],
#  ['286', '542', '939'],
#  ['75', '985', '179'],
#  ['293', '914', '854'],
#  ['234', '609', '877'],
#  ['237', '167', '880'],
#  ['151', '722', '925'],
#  ['793', '515', '278'],
#  ['350', '432', '777'],
#  ['883', '402', '581'],
#  ['621', '501', '702'],
#  ['494', '265', '665'],
#  ['167', '668', '345'],
#  ['853', '911', '629'],
#  ['747', '428', '576'],
#  ['703', '979', '73'],
#  ['938', '798', '401'],
#  ['851', '743', '542'],
#  ['281', '216', '483'],
#  ['772', '573', '404'],
#  ['598', '547', '606'],
#  ['275', '107', '823'],
#  ['92', '94', '864'],
#  ['416', '201', '759'],
#  ['331', '146', '446'],
#  ['200', '375', '70'],
#  ['459', '349', '928'],
#  ['615', '77', '999'],
#  ['748', '380', '628'],
#  ['624', '244', '759'],
#  ['934', '512', '163'],
#  ['964', '117', '75'],
#  ['515', '146', '209'],
#  ['917', '31', '218'],
#  ['694', '640', '116'],
#  ['758', '53', '375'],
#  ['250', '655', '353'],
#  ['153', '200', '189'],
#  ['259', '752', '85'],
#  ['313', '637', '129'],
#  ['361', '632', '973'],
#  ['896', '61', '934'],
#  ['581', '611', '483'],
#  ['620', '788', '889'],
#  ['959', '273', '754'],
#  ['677', '997', '322'],
#  ['43', '201', '714'],
#  ['181', '956', '734'],
#  ['147', '878', '850'],
#  ['139', '802', '938'],
#  ['542', '729', '26'],
#  ['531', '201', '915'],
#  ['412', '917', '301'],
#  ['845', '44', '811'],
#  ['489', '897', '626'],
#  ['378', '384', '781'],
#  ['429', '130', '313'],
#  ['583', '400', '515'],
#  ['811', '937', '949'],
#  ['584', '812', '909'],
#  ['738', '143', '205'],
#  ['79', '813', '801'],
#  ['599', '872', '539'],
#  ['650', '177', '384'],
#  ['299', '267', '539'],
#  ['506', '358', '516'],
#  ['425', '520', '185'],
#  ['901', '854', '622'],
#  ['84', '371', '21'],
#  ['931', '797', '642'],
#  ['274', '155', '432'],
#  ['366', '935', '635'],
#  ['331', '810', '836'],
#  ['56', '725', '67'],
#  ['9', '756', '985'],
#  ['58', '38', '946'],
#  ['385', '807', '899'],
#  ['336', '998', '3'],
#  ['243', '539', '893'],
#  ['792', '117', '272'],
#  ['345', '995', '452'],
#  ['717', '892', '262'],
#  ['311', '694', '23'],
#  ['737', '169', '392'],
#  ['875', '741', '379'],
#  ['609', '422', '100'],
#  ['644', '442', '916'],
#  ['832', '51', '967'],
#  ['230', '962', '82'],
#  ['380', '202', '931'],
#  ['308', '786', '903'],
#  ['556', '668', '121'],
#  ['194', '650', '263'],
#  ['732', '20', '346'],
#  ['528', '445', '589'],
#  ['341', '142', '684'],
#  ['281', '302', '550'],
#  ['408', '511', '219'],
#  ['683', '938', '617'],
#  ['679', '705', '763'],
#  ['812', '847', '313'],
#  ['557', '838', '308'],
#  ['888', '23', '145'],
#  ['120', '20', '129'],
#  ['450', '643', '245'],
#  ['329', '658', '282'],
#  ['30', '878', '700'],
#  ['698', '799', '335'],
#  ['698', '320', '595'],
#  ['875', '959', '595'],
#  ['50', '715', '454'],
#  ['856', '686', '269'],
#  ['986', '38', '589'],
#  ['834', '925', '69'],
#  ['263', '928', '654'],
#  ['430', '175', '586'],
#  ['99', '712', '642'],
#  ['439', '679', '132'],
#  ['639', '714', '644'],
#  ['563', '940', '62'],
#  ['228', '385', '666'],
#  ['758', '757', '949'],
#  ['137', '174', '104'],
#  ['859', '746', '939'],
#  ['675', '140', '592'],
#  ['324', '446', '357'],
#  ['471', '486', '455'],
#  ['450', '429', '980'],
#  ['955', '388', '599'],
#  ['914', '222', '512'],
#  ['981', '673', '871'],
#  ['941', '716', '744'],
#  ['55', '192', '173'],
#  ['98', '48', '411'],
#  ['774', '686', '343'],
#  ['689', '671', '412'],
#  ['666', '613', '686'],
#  ['420', '595', '550'],
#  ['891', '148', '204'],
#  ['150', '678', '978'],
#  ['420', '684', '49'],
#  ['503', '879', '985'],
#  ['95', '508', '231'],
#  ['90', '393', '777'],
#  ['17', '464', '813'],
#  ['372', '120', '26'],
#  ['513', '10', '445'],
#  ['258', '133', '460'],
#  ['392', '29', '355'],
#  ['116', '874', '635'],
#  ['326', '889', '493'],
#  ['883', '599', '250'],
#  ['913', '388', '798'],
#  ['85', '366', '782'],
#  ['422', '416', '204'],
#  ['533', '174', '93'],
#  ['168', '413', '270'],
#  ['617', '996', '461'],
#  ['8', '386', '1'],
#  ['613', '928', '464'],
#  ['455', '545', '619'],
#  ['424', '631', '488'],
#  ['142', '612', '146'],
#  ['921', '374', '324'],
#  ['744', '791', '395'],
#  ['923', '797', '445'],
#  ['876', '447', '602'],
#  ['851', '62', '493'],
#  ['23', '397', '993'],
#  ['232', '602', '90'],
#  ['790', '604', '698'],
#  ['855', '7', '654'],
#  ['350', '105', '561'],
#  ['550', '198', '327'],
#  ['670', '130', '340'],
#  ['904', '943', '765'],
#  ['23', '467', '804'],
#  ['906', '726', '948'],
#  ['337', '90', '774'],
#  ['438', '546', '667'],
#  ['134', '625', '247'],
#  ['334', '282', '729'],
#  ['619', '275', '412'],
#  ['377', '5', '763'],
#  ['250', '722', '852'],
#  ['754', '365', '401'],
#  ['558', '393', '615'],
#  ['974', '673', '39'],
#  ['922', '610', '899'],
#  ['99', '969', '868'],
#  ['89', '616', '911'],
#  ['235', '326', '371'],
#  ['252', '605', '907'],
#  ['429', '387', '678'],
#  ['564', '34', '565'],
#  ['436', '359', '584'],
#  ['125', '780', '474'],
#  ['842', '372', '184'],
#  ['785', '507', '489'],
#  ['849', '418', '633'],
#  ['962', '191', '582'],
#  ['728', '453', '669'],
#  ['91', '970', '639'],
#  ['48', '222', '639'],
#  ['41', '865', '103'],
#  ['395', '765', '945'],
#  ['551', '103', '9'],
#  ['313', '687', '956'],
#  ['952', '109', '894'],
#  ['612', '79', '518'],
#  ['392', '119', '506'],
#  ['106', '739', '427'],
#  ['941', '688', '483'],
#  ['917', '103', '114'],
#  ['326', '466', '604'],
#  ['393', '641', '488'],
#  ['128', '920', '135'],
#  ['609', '742', '725'],
#  ['101', '596', '371'],
#  ['631', '325', '416'],
#  ['318', '939', '170'],
#  ['166', '540', '821'],
#  ['460', '654', '843'],
#  ['672', '942', '330'],
#  ['620', '673', '352'],
#  ['288', '731', '20'],
#  ['263', '277', '387'],
#  ['259', '49', '434'],
#  ['73', '262', '278'],
#  ['525', '775', '36'],
#  ['867', '735', '125'],
#  ['437', '415', '141'],
#  ['567', '537', '640'],
#  ['99', '581', '584'],
#  ['468', '108', '84'],
#  ['608', '997', '893'],
#  ['573', '722', '971'],
#  ['497', '953', '399'],
#  ['201', '184', '372'],
#  ['203', '323', '386'],
#  ['2', '331', '72'],
#  ['375', '687', '307'],
#  ['484', '57', '322'],
#  ['311', '704', '416'],
#  ['720', '961', '571'],
#  ['444', '211', '926'],
#  ['668', '771', '666'],
#  ['742', '688', '146'],
#  ['447', '435', '143'],
#  ['394', '444', '1'],
#  ['450', '39', '373'],
#  ['150', '634', '442'],
#  ['422', '645', '546'],
#  ['132', '562', '281'],
#  ['795', '365', '455'],
#  ['921', '389', '255'],
#  ['17', '153', '85'],
#  ['795', '593', '367'],
#  ['788', '637', '447'],
#  ['292', '297', '703'],
#  ['190', '938', '871'],
#  ['166', '821', '386'],
#  ['437', '636', '385'],
#  ['160', '288', '604'],
#  ['334', '584', '837'],
#  ['701', '207', '665'],
#  ['470', '84', '204'],
#  ['599', '268', '739'],
#  ['634', '92', '148'],
#  ['507', '620', '198'],
#  ['193', '677', '94'],
#  ['301', '990', '536'],
#  ['874', '493', '783'],
#  ['932', '550', '497'],
#  ['81', '166', '546'],
#  ['633', '538', '476'],
#  ['553', '411', '790'],
#  ['593', '159', '316'],
#  ['47', '729', '226'],
#  ['619', '708', '409'],
#  ['38', '535', '763'],
#  ['421', '830', '550'],
#  ['400', '537', '641'],
#  ['275', '531', '166'],
#  ['247', '564', '495'],
#  ['177', '791', '655'],
#  ['959', '363', '548'],
#  ['232', '105', '594'],
#  ['919', '272', '912'],
#  ['258', '467', '505'],
#  ['882', '783', '365'],
#  ['916', '331', '441'],
#  ['70', '815', '204'],
#  ['66', '304', '470'],
#  ['2', '810', '372'],
#  ['734', '276', '875'],
#  ['771', '295', '72'],
#  ['455', '191', '892'],
#  ['765', '384', '195'],
#  ['758', '418', '844'],
#  ['38', '121', '980'],
#  ['302', '379', '606'],
#  ['116', '384', '199'],
#  ['353', '13', '607'],
#  ['712', '805', '790'],
#  ['589', '701', '694'],
#  ['540', '776', '276'],
#  ['985', '814', '61'],
#  ['996', '10', '709'],
#  ['450', '821', '652'],
#  ['715', '26', '899'],
#  ['628', '656', '679'],
#  ['322', '669', '279'],
#  ['144', '649', '518'],
#  ['962', '175', '363'],
#  ['839', '627', '292'],
#  ['931', '934', '378'],
#  ['588', '382', '122'],
#  ['410', '923', '263'],
#  ['652', '680', '654'],
#  ['25', '878', '835'],
#  ['640', '399', '396'],
#  ['492', '202', '511'],
#  ['510', '225', '521'],
#  ['15', '413', '233'],
#  ['493', '551', '122'],
#  ['683', '222', '569'],
#  ['248', '457', '641'],
#  ['100', '936', '315'],
#  ['902', '998', '870'],
#  ['975', '98', '680'],
#  ['998', '309', '653'],
#  ['605', '944', '532'],
#  ['530', '887', '400'],
#  ['572', '879', '925'],
#  ['311', '147', '692'],
#  ['425', '924', '848'],
#  ['453', '945', '934'],
#  ['492', '918', '22'],
#  ['434', '338', '933'],
#  ['288', '297', '665'],
#  ['274', '712', '185'],
#  ['99', '503', '741'],
#  ['868', '523', '263'],
#  ['828', '218', '121'],
#  ['53', '565', '236'],
#  ['15', '409', '778'],
#  ['367', '293', '444'],
#  ['352', '610', '413'],
#  ['892', '970', '706'],
#  ['954', '767', '321'],
#  ['75', '656', '414'],
#  ['823', '781', '57'],
#  ['423', '673', '349'],
#  ['817', '405', '324'],
#  ['768', '19', '345'],
#  ['302', '949', '529'],
#  ['654', '944', '794'],
#  ['262', '766', '959'],
#  ['783', '92', '866'],
#  ['772', '718', '772'],
#  ['629', '154', '669'],
#  ['723', '349', '109'],
#  ['914', '352', '599'],
#  ['559', '746', '346'],
#  ['492', '781', '860'],
#  ['103', '52', '624'],
#  ['655', '397', '857'],
#  ['680', '242', '417'],
#  ['183', '203', '846'],
#  ['714', '519', '457'],
#  ['849', '292', '946'],
#  ['605', '566', '646'],
#  ['793', '653', '156'],
#  ['111', '135', '44'],
#  ['882', '531', '191'],
#  ['920', '773', '378'],
#  ['911', '340', '546'],
#  ['23', '655', '382'],
#  ['656', '708', '587'],
#  ['43', '792', '708'],
#  ['673', '734', '605'],
#  ['506', '725', '943'],
#  ['421', '762', '553'],
#  ['471', '214', '572'],
#  ['195', '575', '438'],
#  ['114', '546', '687'],
#  ['121', '47', '894'],
#  ['744', '221', '820'],
#  ['58', '273', '982'],
#  ['759', '58', '233'],
#  ['770', '824', '785'],
#  ['857', '441', '480'],
#  ['87', '387', '477'],
#  ['838', '633', '28'],
#  ['635', '547', '49'],
#  ['329', '404', '47'],
#  ['534', '955', '933'],
#  ['661', '985', '662'],
#  ['199', '144', '713'],
#  ['228', '996', '622'],
#  ['197', '523', '858'],
#  ['64', '486', '552'],
#  ['859', '968', '422'],
#  ['847', '31', '648'],
#  ['41', '944', '812'],
#  ['625', '953', '830'],
#  ['987', '734', '37'],
#  ['529', '512', '825'],
#  ['104', '690', '688'],
#  ['602', '224', '973'],
#  ['592', '888', '409'],
#  ['241', '247', '639'],
#  ['290', '80', '570'],
#  ['483', '284', '97'],
#  ['322', '223', '57'],
#  ['91', '204', '503'],
#  ['257', '18', '464'],
#  ['904', '480', '177'],
#  ['945', '364', '137'],
#  ['199', '240', '234'],
#  ['231', '177', '23'],
#  ['537', '147', '464'],
#  ['683', '71', '468'],
#  ['448', '55', '544'],
#  ['264', '143', '640'],
#  ['307', '125', '706'],
#  ['674', '384', '373'],
#  ['469', '903', '656'],
#  ['538', '695', '361'],
#  ['461', '942', '728'],
#  ['430', '911', '347'],
#  ['85', '70', '789'],
#  ['422', '525', '65'],
#  ['466', '322', '776'],
#  ['49', '620', '765'],
#  ['832', '530', '9'],
#  ['215', '92', '417'],
#  ['965', '511', '415'],
#  ['865', '888', '289'],
#  ['993', '74', '332'],
#  ['685', '830', '52'],
#  ['11', '334', '151'],
#  ['98', '36', '192'],
#  ['93', '307', '89'],
#  ['38', '483', '498'],
#  ['674', '317', '910'],
#  ['697', '302', '486'],
#  ['267', '29', '508'],
#  ['816', '924', '165'],
#  ['895', '954', '671'],
#  ['629', '75', '634'],
#  ['591', '301', '149'],
#  ['368', '346', '735'],
#  ['916', '606', '382'],
#  ['63', '786', '124'],
#  ['916', '180', '475'],
#  ['466', '656', '218'],
#  ['128', '35', '326'],
#  ['570', '665', '164'],
#  ['181', '382', '773'],
#  ['256', '122', '266'],
#  ['130', '288', '905'],
#  ['288', '524', '40'],
#  ['278', '526', '471'],
#  ['39', '243', '476'],
#  ['951', '16', '522'],
#  ['662', '93', '522'],
#  ['378', '107', '7'],
#  ['218', '520', '10'],
#  ['654', '399', '343'],
#  ['674', '158', '351'],
#  ['854', '320', '834'],
#  ['722', '358', '818'],
#  ['231', '178', '671'],
#  ['862', '892', '764'],
#  ['109', '461', '982'],
#  ['943', '655', '412'],
#  ['745', '541', '255'],
#  ['868', '541', '297'],
#  ['472', '20', '224'],
#  ['163', '991', '647'],
#  ['249', '883', '588'],
#  ['232', '486', '162'],
#  ['236', '281', '784'],
#  ['416', '261', '65'],
#  ['377', '34', '790'],
#  ['357', '121', '610'],
#  ['542', '439', '866'],
#  ['860', '324', '598'],
#  ['865', '337', '712'],
#  ['368', '421', '977'],
#  ['839', '280', '457'],
#  ['140', '655', '416'],
#  ['962', '381', '331'],
#  ['901', '685', '732'],
#  ['818', '483', '831'],
#  ['13', '724', '791'],
#  ['818', '694', '222'],
#  ['746', '822', '841'],
#  ['829', '418', '836'],
#  ['335', '565', '408'],
#  ['516', '447', '281'],
#  ['584', '204', '166'],
#  ['480', '508', '119'],
#  ['713', '787', '704'],
#  ['626', '941', '739'],
#  ['206', '418', '284'],
#  ['989', '326', '701'],
#  ['636', '396', '195'],
#  ['397', '393', '655'],
#  ['240', '696', '896'],
#  ['166', '117', '974'],
#  ['72', '733', '210'],
#  ['797', '533', '566'],
#  ['729', '728', '481'],
#  ['663', '212', '86'],
#  ['298', '475', '563'],
#  ['590', '533', '517'],
#  ['618', '314', '133'],
#  ['422', '195', '38'],
#  ['195', '415', '288'],
#  ['540', '303', '253'],
#  ['446', '553', '859'],
#  ['568', '891', '223'],
#  ['432', '617', '981'],
#  ['519', '214', '775'],
#  ['529', '721', '844'],
#  ['786', '898', '692'],
#  ['440', '401', '201'],
#  ['345', '353', '846'],
#  ['296', '566', '906'],
#  ['638', '422', '370'],
#  ['15', '577', '469'],
#  ['624', '192', '134'],
#  ['136', '554', '755'],
#  ['182', '690', '940'],
#  ['77', '366', '923'],
#  ['284', '979', '275'],
#  ['157', '582', '373'],
#  ['433', '547', '343'],
#  ['767', '786', '527'],
#  ['983', '877', '385'],
#  ['581', '612', '158'],
#  ['365', '520', '673'],
#  ['436', '227', '897'],
#  ['458', '421', '913'],
#  ['579', '492', '760'],
#  ['818', '493', '507'],
#  ['316', '22', '867'],
#  ['114', '421', '939'],
#  ['372', '281', '912'],
#  ['415', '608', '633'],
#  ['938', '676', '927'],
#  ['965', '591', '931'],
#  ['335', '789', '34'],
#  ['865', '820', '346'],
#  ['406', '798', '304'],
#  ['893', '441', '267'],
#  ['166', '126', '835'],
#  ['764', '859', '839'],
#  ['629', '918', '194'],
#  ['557', '297', '552'],
#  ['954', '79', '478'],
#  ['801', '224', '670'],
#  ['640', '493', '262'],
#  ['750', '478', '681'],
#  ['534', '867', '654'],
#  ['980', '586', '142'],
#  ['882', '597', '156'],
#  ['277', '186', '48'],
#  ['448', '541', '23'],
#  ['457', '702', '496'],
#  ['11', '936', '491'],
#  ['689', '668', '457'],
#  ['368', '941', '288'],
#  ['914', '311', '464'],
#  ['893', '843', '828'],
#  ['800', '933', '797'],
#  ['951', '427', '657'],
#  ['754', '215', '476'],
#  ['148', '260', '508'],
#  ['735', '130', '193'],
#  ['390', '631', '761'],
#  ['288', '203', '777'],
#  ['273', '443', '23'],
#  ['189', '20', '355'],
#  ['240', '344', '560'],
#  ['157', '360', '674'],
#  ['921', '774', '803'],
#  ['473', '943', '937'],
#  ['600', '920', '393'],
#  ['611', '579', '530'],
#  ['632', '577', '59'],
#  ['24', '5', '495'],
#  ['701', '358', '722'],
#  ['703', '284', '820'],
#  ['625', '625', '844'],
#  ['649', '253', '531'],
#  ['447', '309', '534'],
#  ['662', '218', '419'],
#  ['762', '347', '627'],
#  ['947', '344', '133'],
#  ['581', '36', '652'],
#  ['222', '747', '122'],
#  ['238', '761', '162'],
#  ['72', '82', '231'],
#  ['717', '296', '966'],
#  ['563', '516', '774'],
#  ['273', '451', '819'],
#  ['956', '175', '651'],
#  ['33', '770', '754'],
#  ['956', '650', '369'],
#  ['146', '838', '148'],
#  ['588', '713', '547'],
#  ['453', '457', '541'],
#  ['979', '92', '401'],
#  ['967', '162', '417'],
#  ['144', '155', '672'],
#  ['725', '737', '962'],
#  ['779', '701', '886'],
#  ['64', '203', '120'],
#  ['433', '284', '482'],
#  ['911', '538', '512'],
#  ['613', '713', '77'],
#  ['268', '636', '685'],
#  ['445', '955', '193'],
#  ['458', '677', '653'],
#  ['91', '450', '356'],
#  ['747', '11', '360'],
#  ['728', '448', '147'],
#  ['37', '494', '679'],
#  ['780', '582', '256'],
#  ['756', '212', '810'],
#  ['556', '434', '265'],
#  ['280', '472', '983'],
#  ['547', '93', '857'],
#  ['922', '225', '378'],
#  ['754', '138', '346'],
#  ['236', '235', '349'],
#  ['718', '421', '501'],
#  ['80', '880', '464'],
#  ['753', '490', '286'],
#  ['616', '332', '218'],
#  ['338', '391', '547'],
#  ['490', '599', '370'],
#  ['35', '559', '686'],
#  ['67', '290', '565'],
#  ['30', '597', '153'],
#  ['59', '763', '701'],
#  ['268', '439', '123'],
#  ['237', '940', '669'],
#  ['451', '205', '145'],
#  ['302', '284', '961'],
#  ['365', '443', '828'],
#  ['225', '598', '65'],
#  ['437', '561', '73'],
#  ['248', '219', '7'],
#  ['72', '29', '274'],
#  ['577', '35', '654'],
#  ['537', '41', '857'],
#  ['956', '966', '739'],
#  ['545', '747', '373'],
#  ['479', '463', '705'],
#  ['112', '79', '161'],
#  ['280', '885', '672'],
#  ['322', '829', '596'],
#  ['422', '279', '697'],
#  ['804', '997', '963'],
#  ['907', '852', '494'],
#  ['321', '245', '492'],
#  ['298', '698', '419'],
#  ['49', '454', '185'],
#  ['169', '214', '25'],
#  ['880', '324', '414'],
#  ['816', '163', '425'],
#  ['366', '370', '167'],
#  ['729', '49', '684'],
#  ['460', '337', '792'],
#  ['719', '908', '817'],
#  ['825', '310', '303'],
#  ['245', '814', '724'],
#  ['877', '713', '128'],
#  ['488', '241', '839'],
#  ['499', '820', '884'],
#  ['918', '356', '273'],
#  ['69', '228', '442'],
#  ['877', '523', '698'],
#  ['780', '391', '627'],
#  ['838', '539', '547'],
#  ['512', '867', '786'],
#  ['491', '298', '421'],
#  ['402', '153', '940'],
#  ['602', '220', '539'],
#  ['638', '167', '534'],
#  ['626', '204', '122'],
#  ['77', '170', '569'],
#  ['342', '364', '529'],
#  ['74', '523', '842'],
#  ['416', '675', '415'],
#  ['292', '900', '918'],
#  ['335', '565', '795'],
#  ['145', '396', '558'],
#  ['320', '421', '585'],
#  ['315', '495', '106'],
#  ['618', '492', '494'],
#  ['985', '684', '702'],
#  ['261', '35', '699'],
#  ['890', '678', '100'],
#  ['797', '972', '693'],
#  ['782', '12', '675'],
#  ['991', '963', '24'],
#  ['774', '465', '254'],
#  ['409', '446', '291'],
#  ['920', '178', '430'],
#  ['558', '186', '476'],
#  ['668', '502', '39'],
#  ['897', '497', '471'],
#  ['927', '534', '95'],
#  ['465', '621', '535'],
#  ['971', '718', '597'],
#  ['440', '803', '941'],
#  ['859', '104', '59'],
#  ['891', '712', '889'],
#  ['7', '465', '712'],
#  ['928', '323', '951'],
#  ['938', '251', '464'],
#  ['939', '541', '491'],
#  ['376', '430', '543'],
#  ['605', '181', '684'],
#  ['849', '578', '57'],
#  ['635', '433', '572'],
#  ['958', '171', '565'],
#  ['525', '870', '63'],
#  ['198', '864', '591'],
#  ['466', '125', '610'],
#  ['442', '604', '512'],
#  ['444', '666', '55'],
#  ['129', '374', '546'],
#  ['893', '328', '978'],
#  ['78', '279', '999'],
#  ['852', '302', '465'],
#  ['378', '619', '123'],
#  ['97', '246', '185'],
#  ['374', '775', '308'],
#  ['579', '48', '388'],
#  ['497', '730', '745'],
#  ['142', '703', '596'],
#  ['387', '31', '973'],
#  ['861', '944', '602'],
#  ['894', '919', '522'],
#  ['755', '689', '409'],
#  ['592', '310', '115'],
#  ['326', '708', '398'],
#  ['53', '87', '866'],
#  ['966', '266', '370'],
#  ['925', '281', '815'],
#  ['864', '315', '882'],
#  ['699', '352', '849'],
#  ['526', '185', '948'],
#  ['58', '454', '681'],
#  ['496', '917', '237'],
#  ['556', '907', '558'],
#  ['815', '422', '705'],
#  ['232', '423', '194'],
#  ['941', '811', '583'],
#  ['686', '207', '335'],
#  ['637', '693', '440'],
#  ['574', '795', '385'],
#  ['531', '936', '899'],
#  ['721', '950', '37'],
#  ['317', '786', '906'],
#  ['830', '719', '101'],
#  ['360', '615', '650'],
#  ['689', '218', '676'],
#  ['790', '208', '197'],
#  ['621', '7', '791'],
#  ['868', '203', '866'],
#  ['16', '491', '53'],
#  ['952', '268', '717'],
#  ['956', '736', '773'],
#  ['793', '386', '760'],
#  ['750', '624', '957'],
#  ['184', '964', '443'],
#  ['454', '684', '835'],
#  ['439', '931', '60'],
#  ['293', '434', '866'],
#  ['990', '467', '282'],
#  ['664', '423', '302'],
#  ['523', '485', '116'],
#  ['127', '469', '710'],
#  ['625', '758', '497'],
#  ['514', '544', '998'],
#  ['571', '281', '413'],
#  ['458', '70', '645'],
#  ['526', '283', '884'],
#  ['77', '738', '725'],
#  ['802', '278', '508'],
#  ['782', '597', '976'],
#  ['385', '358', '919'],
#  ['710', '492', '994'],
#  ['750', '517', '79'],
#  ['964', '231', '679'],
#  ['370', '34', '845'],
#  ['951', '245', '299'],
#  ['83', '431', '846'],
#  ['384', '989', '609'],
#  ['447', '761', '747'],
#  ['647', '898', '371'],
#  ['95', '794', '298'],
#  ['644', '157', '625'],
#  ['663', '107', '507'],
#  ['572', '927', '578'],
#  ['165', '926', '94'],
#  ['455', '530', '905'],
#  ['397', '412', '598'],
#  ['616', '239', '788'],
#  ['228', '556', '609'],
#  ['26', '540', '184'],
#  ['208', '745', '687'],
#  ['877', '36', '977'],
#  ['64', '29', '195'],
#  ['936', '56', '807'],
#  ['952', '253', '397'],
#  ['62', '246', '95'],
#  ['923', '102', '491'],
#  ['576', '116', '739'],
#  ['919', '559', '820'],
#  ['882', '534', '865'],
#  ['490', '650', '961'],
#  ['441', '741', '975'],
#  ['59', '922', '597'],
#  ['76', '209', '337'],
#  ['293', '785', '447'],
#  ['338', '971', '276'],
#  ['117', '581', '939'],
#  ['210', '266', '701'],
#  ['108', '448', '378'],
#  ['253', '556', '164'],
#  ['998', '200', '168'],
#  ['969', '358', '13'],
#  ['606', '206', '458'],
#  ['752', '400', '571'],
#  ['796', '521', '911'],
#  ['934', '50', '150'],
#  ['96', '205', '764'],
#  ['844', '216', '657'],
#  ['669', '434', '222'],
#  ['242', '301', '66'],
#  ['471', '277', '227'],
#  ['732', '681', '20'],
#  ['67', '991', '597'],
#  ['784', '793', '613'],
#  ['198', '841', '555'],
#  ['109', '429', '396'],
#  ['219', '461', '729'],
#  ['128', '255', '888'],
#  ['850', '154', '754'],
#  ['809', '226', '387'],
#  ['719', '468', '706'],
#  ['289', '436', '26'],
#  ['441', '280', '688'],
#  ['510', '57', '451'],
#  ['417', '255', '277'],
#  ['670', '198', '625'],
#  ['791', '681', '20'],
#  ['803', '998', '294'],
#  ['332', '323', '282'],
#  ['905', '213', '739'],
#  ['115', '267', '394'],
#  ['965', '213', '788'],
#  ['125', '829', '635'],
#  ['90', '281', '640'],
#  ['103', '584', '81'],
#  ['407', '771', '19'],
#  ['205', '213', '708'],
#  ['380', '814', '704'],
#  ['778', '462', '872'],
#  ['799', '553', '758'],
#  ['402', '193', '269'],
#  ['403', '947', '198'],
#  ['814', '22', '499'],
#  ['532', '948', '570'],
#  ['159', '951', '932'],
#  ['505', '616', '592'],
#  ['507', '657', '785'],
#  ['811', '860', '675'],
#  ['831', '140', '99'],
#  ['450', '966', '627'],
#  ['939', '358', '947'],
#  ['182', '201', '1'],
#  ['951', '487', '951'],
#  ['367', '376', '539'],
#  ['972', '491', '495'],
#  ['758', '761', '80'],
#  ['122', '872', '278'],
#  ['933', '927', '926'],
#  ['835', '300', '759'],
#  ['733', '195', '418'],
#  ['347', '73', '485'],
#  ['783', '138', '660'],
#  ['186', '586', '422'],
#  ['464', '301', '410'],
#  ['479', '552', '175'],
#  ['532', '634', '83'],
#  ...]

# %%
# Check each ordering of each group for valid triangle lengths
for x in vtri:
    t = [int(each) for each in x]
    a, b, c = t

    if (a == max(t) and (b + c > a)) or (b == max(t) and (c + a > b)) or (c == max(t) and (a + b > c)):
        count += 1
    
print count
# Out:
# 1836

# %%
print zip(*htri)[0]
# Out:
# ('4', '419', '424', '651', '655', '2', '736', '657', '252', '532', '574', '157', '468', '502', '467', '911', '791', '174', '796', '800', '273', '388', '17', '371', '692', '745', '381', '859', '109', '835', '355', '968', '979', '134', '614', '510', '901', '958', '95', '676', '890', '280', '593', '555', '39', '399', '293', '109', '260', '306', '49', '125', '706', '728', '410', '617', '923', '462', '352', '129', '648', '332', '947', '768', '672', '98', '368', '271', '141', '731', '734', '16', '133', '428', '398', '154', '643', '695', '22', '490', '474', '902', '996', '91', '653', '439', '480', '156', '492', '408', '469', '777', '803', '78', '567', '542', '286', '75', '293', '234', '237', '151', '793', '350', '883', '621', '494', '167', '853', '747', '703', '938', '851', '281', '772', '598', '275', '92', '416', '331', '200', '459', '615', '748', '624', '934', '964', '515', '917', '694', '758', '250', '153', '259', '313', '361', '896', '581', '620', '959', '677', '43', '181', '147', '139', '542', '531', '412', '845', '489', '378', '429', '583', '811', '584', '738', '79', '599', '650', '299', '506', '425', '901', '84', '931', '274', '366', '331', '56', '9', '58', '385', '336', '243', '792', '345', '717', '311', '737', '875', '609', '644', '832', '230', '380', '308', '556', '194', '732', '528', '341', '281', '408', '683', '679', '812', '557', '888', '120', '450', '329', '30', '698', '698', '875', '50', '856', '986', '834', '263', '430', '99', '439', '639', '563', '228', '758', '137', '859', '675', '324', '471', '450', '955', '914', '981', '941', '55', '98', '774', '689', '666', '420', '891', '150', '420', '503', '95', '90', '17', '372', '513', '258', '392', '116', '326', '883', '913', '85', '422', '533', '168', '617', '8', '613', '455', '424', '142', '921', '744', '923', '876', '851', '23', '232', '790', '855', '350', '550', '670', '904', '23', '906', '337', '438', '134', '334', '619', '377', '250', '754', '558', '974', '922', '99', '89', '235', '252', '429', '564', '436', '125', '842', '785', '849', '962', '728', '91', '48', '41', '395', '551', '313', '952', '612', '392', '106', '941', '917', '326', '393', '128', '609', '101', '631', '318', '166', '460', '672', '620', '288', '263', '259', '73', '525', '867', '437', '567', '99', '468', '608', '573', '497', '201', '203', '2', '375', '484', '311', '720', '444', '668', '742', '447', '394', '450', '150', '422', '132', '795', '921', '17', '795', '788', '292', '190', '166', '437', '160', '334', '701', '470', '599', '634', '507', '193', '301', '874', '932', '81', '633', '553', '593', '47', '619', '38', '421', '400', '275', '247', '177', '959', '232', '919', '258', '882', '916', '70', '66', '2', '734', '771', '455', '765', '758', '38', '302', '116', '353', '712', '589', '540', '985', '996', '450', '715', '628', '322', '144', '962', '839', '931', '588', '410', '652', '25', '640', '492', '510', '15', '493', '683', '248', '100', '902', '975', '998', '605', '530', '572', '311', '425', '453', '492', '434', '288', '274', '99', '868', '828', '53', '15', '367', '352', '892', '954', '75', '823', '423', '817', '768', '302', '654', '262', '783', '772', '629', '723', '914', '559', '492', '103', '655', '680', '183', '714', '849', '605', '793', '111', '882', '920', '911', '23', '656', '43', '673', '506', '421', '471', '195', '114', '121', '744', '58', '759', '770', '857', '87', '838', '635', '329', '534', '661', '199', '228', '197', '64', '859', '847', '41', '625', '987', '529', '104', '602', '592', '241', '290', '483', '322', '91', '257', '904', '945', '199', '231', '537', '683', '448', '264', '307', '674', '469', '538', '461', '430', '85', '422', '466', '49', '832', '215', '965', '865', '993', '685', '11', '98', '93', '38', '674', '697', '267', '816', '895', '629', '591', '368', '916', '63', '916', '466', '128', '570', '181', '256', '130', '288', '278', '39', '951', '662', '378', '218', '654', '674', '854', '722', '231', '862', '109', '943', '745', '868', '472', '163', '249', '232', '236', '416', '377', ...

# %%
print htri
# Out:
# [['4', '21', '894'], ['419', '794', '987'], ['424', '797', '125'], ['651', '305', '558'], ['655', '631', '963'], ['2', '628', '436'], ['736', '50', '363'], ['657', '707', '408'], ['252', '705', '98'], ['532', '173', '878'], ['574', '792', '854'], ['157', '737', '303'], ['468', '76', '580'], ['502', '503', '434'], ['467', '567', '310'], ['911', '911', '391'], ['791', '913', '925'], ['174', '49', '532'], ['796', '803', '426'], ['800', '132', '710'], ['273', '722', '711'], ['388', '576', '551'], ['17', '936', '676'], ['371', '712', '141'], ['692', '738', '913'], ['745', '805', '975'], ['381', '140', '680'], ['859', '344', '336'], ['109', '148', '877'], ['835', '441', '716'], ['355', '288', '669'], ['968', '259', '517'], ['979', '350', '773'], ['134', '222', '347'], ['614', '279', '628'], ['510', '140', '590'], ['901', '581', '707'], ['958', '933', '680'], ['95', '558', '766'], ['676', '739', '739'], ['890', '40', '825'], ['280', '735', '297'], ['593', '354', '701'], ['555', '756', '730'], ['39', '656', '853'], ['399', '660', '14'], ['293', '685', '48'], ['109', '374', '42'], ['260', '608', '680'], ['306', '885', '603'], ['49', '683', '810'], ['125', '513', '512'], ['706', '600', '143'], ['728', '138', '658'], ['410', '673', '27'], ['617', '872', '89'], ['923', '733', '103'], ['462', '674', '95'], ['352', '718', '191'], ['129', '351', '173'], ['648', '839', '828'], ['332', '829', '789'], ['947', '44', '214'], ['768', '576', '184'], ['672', '900', '601'], ['98', '672', '738'], ['368', '926', '539'], ['271', '300', '372'], ['141', '844', '261'], ['731', '426', '205'], ['734', '979', '792'], ['16', '703', '888'], ['133', '682', '323'], ['428', '784', '182'], ['398', '171', '394'], ['154', '845', '425'], ['643', '14', '775'], ['695', '849', '432'], ['22', '227', '464'], ['490', '544', '485'], ['474', '701', '910'], ['902', '629', '10'], ['996', '680', '67'], ['91', '908', '75'], ['653', '600', '845'], ['439', '53', '117'], ['480', '552', '860'], ['156', '144', '46'], ['492', '359', '597'], ['408', '473', '614'], ['469', '343', '737'], ['777', '438', '149'], ['803', '114', '676'], ['78', '835', '753'], ['567', '230', '707'], ['542', '738', '49'], ['286', '542', '939'], ['75', '985', '179'], ['293', '914', '854'], ['234', '609', '877'], ['237', '167', '880'], ['151', '722', '925'], ['793', '515', '278'], ['350', '432', '777'], ['883', '402', '581'], ['621', '501', '702'], ['494', '265', '665'], ['167', '668', '345'], ['853', '911', '629'], ['747', '428', '576'], ['703', '979', '73'], ['938', '798', '401'], ['851', '743', '542'], ['281', '216', '483'], ['772', '573', '404'], ['598', '547', '606'], ['275', '107', '823'], ['92', '94', '864'], ['416', '201', '759'], ['331', '146', '446'], ['200', '375', '70'], ['459', '349', '928'], ['615', '77', '999'], ['748', '380', '628'], ['624', '244', '759'], ['934', '512', '163'], ['964', '117', '75'], ['515', '146', '209'], ['917', '31', '218'], ['694', '640', '116'], ['758', '53', '375'], ['250', '655', '353'], ['153', '200', '189'], ['259', '752', '85'], ['313', '637', '129'], ['361', '632', '973'], ['896', '61', '934'], ['581', '611', '483'], ['620', '788', '889'], ['959', '273', '754'], ['677', '997', '322'], ['43', '201', '714'], ['181', '956', '734'], ['147', '878', '850'], ['139', '802', '938'], ['542', '729', '26'], ['531', '201', '915'], ['412', '917', '301'], ['845', '44', '811'], ['489', '897', '626'], ['378', '384', '781'], ['429', '130', '313'], ['583', '400', '515'], ['811', '937', '949'], ['584', '812', '909'], ['738', '143', '205'], ['79', '813', '801'], ['599', '872', '539'], ['650', '177', '384'], ['299', '267', '539'], ['506', '358', '516'], ['425', '520', '185'], ['901', '854', '622'], ['84', '371', '21'], ['931', '797', '642'], ['274', '155', '432'], ['366', '935', '635'], ['331', '810', '836'], ['56', '725', '67'], ['9', '756', '985'], ['58', '38', '946'], ['385', '807', '899'], ['336', '998', '3'], ['243', '539', '893'], ['792', '117', '272'], ['345', '995', '452'], ['717', ' ...
